# %%
import rasterio
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
mnist = tf.keras.datasets.mnist
(x_train, _), (_, _) = mnist.load_data()
image_data = x_train[1]

# %%
plt.imshow(image_data)

# %%
image_process_input = image_data.reshape((28,28,1))

# %%
plt.imshow(tf.image.flip_left_right(image_process_input))

# %%
plt.imshow(tf.image.resize(image_process_input,(64,64)))
